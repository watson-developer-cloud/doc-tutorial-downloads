# %%
import watson_nlp

# %%
import io, os, types, zipfile
from ibm_watson_studio_lib import access_project_or_space
wslib = access_project_or_space()

raw_data_0 = wslib.load_data('Financial+demo+extractor-labeled_data.zip')

training_data_path = 'training_data'
training_zip_filename = 'training.zip'

with io.FileIO(training_zip_filename, 'w') as file:
    for b in raw_data_0:
        file.write(b)

with zipfile.ZipFile(training_zip_filename) as zObject:
    zObject.extractall(path=".")

if not os.path.exists(training_data_path):
    os.mkdir(training_data_path)
os.rename('./labeled_data.json', f"./{training_data_path}/labeled_data.json")

# %%
from watson_nlp.toolkit.entity_mentions_utils.train_util import prepare_stream_of_train_records_from_JSON_collection

syntax_models = [watson_nlp.load('syntax_izumo_en_stock')]

train_data_stream = prepare_stream_of_train_records_from_JSON_collection(training_data_path)

train_data_stream, dev_data_stream = train_data_stream.train_test_split(
    test_split=0.2,
    seed=123,
)

pretrained_model_resource = watson_nlp.load('pretrained-model_slate.153m.distilled_many_transformer_multilingual_uncased')


trained_workflow = watson_nlp.workflows.entity_mentions.transformer.Transformer.train(
    train_data_stream=train_data_stream,
    dev_data_stream=dev_data_stream,
    syntax_models=syntax_models,
    template_resource=pretrained_model_resource,
    learning_rate=1.00E-04,
    num_train_epochs=20,
    warmup_ratio=5/50,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=32
)
# Out:
# [WARNING|modeling_utils.py:1704] 2023-10-25 03:02:02,052 >> Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at /opt/ibm/nlpmodels/pretrained-model_slate.153m.distilled_many_transformer_multilingual_uncased/artifacts and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** train metrics *****
#   epoch                    =       20.0
#   total_flos               =     7559GF
#   train_loss               =     0.8268
#   train_runtime            = 0:02:07.68
#   train_samples            =         73
#   train_samples_per_second =     11.434
#   train_steps_per_second   =      0.313

# %%
text = "Fiscal 2010 Financial Results\r\rFiscal 2010 was a year of record performance for our company. Each of our brands ended the year stronger than it began, and aggressive and proactive initiatives across the organization led to new milestones in profitability. We are pleased with the progress we made in merchandising, marketing, customer acquisition and customer service, as it was these initiatives that we believe have allowed us to attract new customers to our brands and gain profitable market share all year. In fiscal 2010, our net revenues increased 12.9% to $3,504,158,000 compared to $3,102,704,000 in fiscal 2009 and we increased our fiscal 2010 diluted earnings per share to $1.83 versus $0.72 in fiscal 2009. We also ended the year with $628,403,000 in cash after returning nearly $185,000,000 to our shareholders through stock repurchases and dividends.\r\rIn our direct-to-customer channel, net revenues in fiscal 2010 increased by $227,902,000, or 18.6%, compared to fiscal 2009. This increase was driven by 26.9% growth in Internet net revenues in fiscal 2010 compared to fiscal 2009. Increased net revenues during fiscal 2010 were driven by the Pottery Barn, Pottery Barn Kids and PBteen brands.\r\rRetail net revenues in fiscal 2010 increased by $173,552,000, or 9.2%, compared to fiscal 2009. This increase was driven by growth of 9.8% in comparable store sales, partially offset by a 4.1% year-over-year reduction in retail leased square footage, including 18 net fewer stores. Increased net revenues during fiscal 2010 were driven by the Pottery Barn, West Elm and Williams-Sonoma brands.\r\rIn our core brands, net revenues increased 12.3% compared to fiscal 2009 led by growth in the Pottery Barn brand. Sales trends improved in every concept and we saw significant growth in new customer acquisition.\r\rIn our emerging brands, net revenues increased 17.1% led by West Elm and PBteen, which continued to see net revenue and operating margin increases. In Williams-Sonoma Home, we completed the retail restructuring of the brand by closing all stand-alone retail stores."

# %%
trained_workflow.run(text, "en")
# Out:
# {
#   "mentions": [
#     {
#       "span": {
#         "begin": 0,
#         "end": 11,
#         "text": "Fiscal 2010"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.523390297380134,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 31,
#         "end": 42,
#         "text": "Fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.4390660249160806,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 122,
#         "end": 126,
#         "text": "year"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.29904913902282715,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 514,
#         "end": 525,
#         "text": "fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6631611080980921,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 544,
#         "end": 553,
#         "text": "increased"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.76274573802948,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 554,
#         "end": 559,
#         "text": "12.9%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.7572389322140781,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 563,
#         "end": 577,
#         "text": "$3,504,158,000"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.8904058787122571,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 590,
#         "end": 604,
#         "text": "$3,102,704,000"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.8831734986360865,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 608,
#         "end": 619,
#         "text": "fiscal 2009"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6766198706912813,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 627,
#         "end": 636,
#         "text": "increased"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.6580868363380432,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 641,
#         "end": 652,
#         "text": "fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.5405941527641279,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 683,
#         "end": 688,
#         "text": "$1.83"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.899352078166309,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 696,
#         "end": 701,
#         "text": "$0.72"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.8948201741987647,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 705,
#         "end": 716,
#         "text": "fiscal 2009"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6705552561757157,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 746,
#         "end": 758,
#         "text": "$628,403,000"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.8994430345362349,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 783,
#         "end": 789,
#         "text": "nearly"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.41280850768089294,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 790,
#         "end": 802,
#         "text": "$185,000,000"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.917332451650654,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 916,
#         "end": 927,
#         "text": "fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6647493478549671,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 928,
#         "end": 937,
#         "text": "increased"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.684819221496582,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 941,
#         "end": 953,
#         "text": "$227,902,000"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.9153027572556464,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 958,
#         "end": 963,
#         "text": "18.6%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.7058830351908431,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 977,
#         "end": 988,
#         "text": "fiscal 2009"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6413976481599415,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 995,
#         "end": 1003,
#         "text": "increase"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.7129239439964294,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1018,
#         "end": 1023,
#         "text": "26.9%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.7701722444231336,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1024,
#         "end": 1030,
#         "text": "growth"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.5141538381576538,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1059,
#         "end": 1070,
#         "text": "fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6919068922011606,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1083,
#         "end": 1094,
#         "text": "fiscal 2009"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6724939478347295,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1126,
#         "end": 1137,
#         "text": "fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.5568593007586379,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1157,
#         "end": 1169,
#         "text": "Pottery Barn"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.7277697354064843,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1171,
#         "end": 1188,
#         "text": "Pottery Barn Kids"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.7551534601451759,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1193,
#         "end": 1199,
#         "text": "PBteen"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.4099191725254059,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1232,
#         "end": 1243,
#         "text": "fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6611190621478723,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1244,
#         "end": 1253,
#         "text": "increased"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.7630180716514587,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1257,
#         "end": 1269,
#         "text": "$173,552,000"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.9162900547525731,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1274,
#         "end": 1278,
#         "text": "9.2%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.8203247128390861,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1292,
#         "end": 1303,
#         "text": "fiscal 2009"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.6566165733659317,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1310,
#         "end": 1318,
#         "text": "increase"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.6920336484909058,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1333,
#         "end": 1339,
#         "text": "growth"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.6133855581283569,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1343,
#         "end": 1347,
#         "text": "9.8%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.7508735775528478,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1397,
#         "end": 1401,
#         "text": "4.1%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.7769378629140611,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1521,
#         "end": 1532,
#         "text": "fiscal 2010"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.5798464547452314,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1552,
#         "end": 1564,
#         "text": "Pottery Barn"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.6779705352651841,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1566,
#         "end": 1574,
#         "text": "West Elm"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.5826873168297885,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1579,
#         "end": 1594,
#         "text": "Williams-Sonoma"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.5115859121025702,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1637,
#         "end": 1646,
#         "text": "increased"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.8509455919265747,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1647,
#         "end": 1652,
#         "text": "12.3%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.759388853582132,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1665,
#         "end": 1676,
#         "text": "fiscal 2009"
#       },
#       "type": "EARNINGS_PERIOD",
#       "producer_id": null,
#       "confidence": 0.5699814420819219,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1698,
#         "end": 1710,
#         "text": "Pottery Barn"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.8135587922187736,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1731,
#         "end": 1739,
#         "text": "improved"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.6927507519721985,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1854,
#         "end": 1863,
#         "text": "increased"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.8483147025108337,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1864,
#         "end": 1869,
#         "text": "17.1%"
#       },
#       "type": "VALUE",
#       "producer_id": null,
#       "confidence": 0.7131309648532419,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1877,
#         "end": 1885,
#         "text": "West Elm"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.5833544905696466,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1954,
#         "end": 1963,
#         "text": "increases"
#       },
#       "type": "FINANCIAL_OUTCOME",
#       "producer_id": null,
#       "confidence": 0.739492654800415,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 1968,
#         "end": 1988,
#         "text": "Williams-Sonoma Home"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.5653124640126502,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 2068,
#         "end": 2074,
#         "text": "retail"
#       },
#       "type": "PRODUCT_SERVICE",
#       "producer_id": null,
#       "confidence": 0.3857469856739044,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     }
#   ],
#   "producer_id": {
#     "name": "Entity-Mentions Transformer Workflow",
#     "version": "0.0.1"
#   }
# }

# %%
from ibm_watson_machine_learning import APIClient

cp4d_hostname = "#### REPLACE WITH YOUR CP4D HOSTNAME, e.g. https://cpd-cp4d-instances.apps.yourdomain.cp.com ####"
wml_credentials = {
    "url": cp4d_hostname,
    "token": wslib.auth.get_current_token(),
    "instance_id": "wml_local",
    "version" : "4.7"
}
client = APIClient(wml_credentials)
client.spaces.list()
# Out:
# Note: 'limit' is not provided. Only first 50 records will be displayed if the number of records exceed 50
# ------------------------------------  ----  ------------------------
# ID                                    NAME  CREATED
# f0610e22-de4e-47d0-86e3-898f5425fa1d  test  2023-10-17T03:15:04.366Z
# ------------------------------------  ----  ------------------------
#                                      ID  NAME                   CREATED
# 0  f0610e22-de4e-47d0-86e3-898f5425fa1d  test  2023-10-17T03:15:04.366Z

# %%
model_name = "Financial demo"
space_id = "#### REPLACe WITH YOUR SPACE ID, e.g. f0610e22-de4e-47d0-86e3-898f5425fa1d in the above list ####"
wslib = access_project_or_space({
    'space_id': space_id
})
wslib.save_data(model_name, trained_workflow.as_bytes(), overwrite=True)
# Out:
# {'name': 'Financial demo',
#  'asset_type': 'data_asset',
#  'asset_id': 'f8f18836-3301-4189-9399-95bad3a5b811',
#  'attachment_id': '29374eff-0091-48f2-9969-781caed4cc52',
#  'filepath': 'Financial demo.',
#  'data_size': None,
#  'mime': 'application/binary',
#  'summary': ['created or overwritten file',
#   'created data asset',
#   'created attachment']}

# %%
client.set.default_space(space_id)
# Out:
# 'SUCCESS'

# %%
def extract_entities():
    import watson_nlp
    from ibm_watson_studio_lib import access_project_or_space
    wslib = access_project_or_space()
    loaded = wslib.load_data("Financial demo") # change here if you change model_name
    entity_model = watson_nlp.load(loaded)
    def score(input):
        scoring_prediction_out = []
        for input_data_row in input["input_data"][0]["values"]:
            scoring_prediction_row = []
            for input_data in input_data_row:
                prediction = entity_model.run(input_data, 'en').to_dict()
                scoring_prediction_row.append(prediction)
            scoring_prediction_out.append(scoring_prediction_row)
        scoring_response = {
            'predictions': [{'fields': ['nlp_prediction'], 'values': scoring_prediction_out}]
        }
        return scoring_response
    return score

# %%
pyfunc_swspec_id = client.software_specifications.get_uid_by_name("runtime-22.2-py3.10")

metadata = {
    client.repository.FunctionMetaNames.NAME: f"{model_name}-function",
    client.repository.FunctionMetaNames.DESCRIPTION: f"function using {model_name} model",
    client.repository.FunctionMetaNames.SOFTWARE_SPEC_UID: pyfunc_swspec_id
}

entity_extractor_details = client.repository.store_function(meta_props=metadata, function=extract_entities)

# %%
entity_extractor_uid = client.repository.get_function_uid(entity_extractor_details)

meta_props = {
    client.deployments.ConfigurationMetaNames.NAME: f"{model_name}-deploy",
    client.deployments.ConfigurationMetaNames.HARDWARE_SPEC: { 'name': 'S'},  
    client.deployments.ConfigurationMetaNames.ONLINE: {}
}


entity_deployment_details = client.deployments.create(entity_extractor_uid, meta_props=meta_props)
entity_deployment_id = client.deployments.get_uid(entity_deployment_details)
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '35bb7573-549e-4130-a774-ed16f24644c7' started
#
# #######################################################################################
#
#
# initializing
# Note: online_url is deprecated and will be removed in a future release. Use serving_urls instead.
# .........
# ready
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='973046bd-2f4e-4afa-90e6-6d831c7d9aa2'
# ------------------------------------------------------------------------------------------------

# %%
scoring_payload = {
    client.deployments.ScoringMetaNames.INPUT_DATA: [{
        'fields': ["text"],
        'values': [[text]]
    }]
}
predictions = client.deployments.score(entity_deployment_id, scoring_payload)
predictions
# Out:
# {'predictions': [{'fields': ['nlp_prediction'],
#    'values': [[{'mentions': [{'span': {'begin': 0,
#          'end': 11,
#          'text': 'Fiscal 2010'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.5233900182453832,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 31, 'end': 42, 'text': 'Fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.43906629349821147,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 122, 'end': 126, 'text': 'year'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.2990490794181824,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 514, 'end': 525, 'text': 'fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6631609279050856,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 544, 'end': 553, 'text': 'increased'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.7627456784248352,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 554, 'end': 559, 'text': '12.9%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.7572389534681574,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 563, 'end': 577, 'text': '$3,504,158,000'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.8904060313858165,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 590, 'end': 604, 'text': '$3,102,704,000'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.8831736461527405,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 608, 'end': 619, 'text': 'fiscal 2009'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6766197900976398,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 627, 'end': 636, 'text': 'increased'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.6580870151519775,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 641, 'end': 652, 'text': 'fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.5405943033949949,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 683, 'end': 688, 'text': '$1.83'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.8993519885372755,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 696, 'end': 701, 'text': '$0.72'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.894820022317816,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 705, 'end': 716, 'text': 'fiscal 2009'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6705552687624753,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 746, 'end': 758, 'text': '$628,403,000'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.8994431255129146,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 783, 'end': 789, 'text': 'nearly'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.41280895471572876,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 790, 'end': 802, 'text': '$185,000,000'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.9173324547400229,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 916, 'end': 927, 'text': 'fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6647494406616946,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 928, 'end': 937, 'text': 'increased'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.6848193407058716,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 941, 'end': 953, 'text': '$227,902,000'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.9153028756561279,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 958, 'end': 963, 'text': '18.6%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.7058831375188471,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 977, 'end': 988, 'text': 'fiscal 2009'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6413977678007579,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 995, 'end': 1003, 'text': 'increase'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.7129237055778503,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1018, 'end': 1023, 'text': '26.9%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.7701719082933648,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1024, 'end': 1030, 'text': 'growth'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.5141534209251404,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1059, 'end': 1070, 'text': 'fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6919068675087856,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1083, 'end': 1094, 'text': 'fiscal 2009'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6724937654999845,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1126, 'end': 1137, 'text': 'fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.5568594374303054,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1157, 'end': 1169, 'text': 'Pottery Barn'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.7277696135060022,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1171, 'end': 1188, 'text': 'Pottery Barn Kids'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.7551537822716411,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1193, 'end': 1199, 'text': 'PBteen'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.4099195897579193,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1232, 'end': 1243, 'text': 'fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6611190099326154,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1244, 'end': 1253, 'text': 'increased'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.7630177736282349,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1257, 'end': 1269, 'text': '$173,552,000'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.9162899951451974,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1274, 'end': 1278, 'text': '9.2%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.8203243233906697,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1292, 'end': 1303, 'text': 'fiscal 2009'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.6566166079919302,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1310, 'end': 1318, 'text': 'increase'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.6920336484909058,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1333, 'end': 1339, 'text': 'growth'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.6133856773376465,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1343, 'end': 1347, 'text': '9.8%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.7508735149225161,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1397, 'end': 1401, 'text': '4.1%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.7769378713488938,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1521, 'end': 1532, 'text': 'fiscal 2010'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.5798465700495522,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1552, 'end': 1564, 'text': 'Pottery Barn'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.6779707698291283,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1566, 'end': 1574, 'text': 'West Elm'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.5826874137460597,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1579, 'end': 1594, 'text': 'Williams-Sonoma'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.5115858998345633,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1637, 'end': 1646, 'text': 'increased'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.8509452939033508,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1647, 'end': 1652, 'text': '12.3%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.7593884501269881,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1665, 'end': 1676, 'text': 'fiscal 2009'},
#         'type': 'EARNINGS_PERIOD',
#         'producer_id': None,
#         'confidence': 0.5699812677429072,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1698, 'end': 1710, 'text': 'Pottery Barn'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.8135588287461307,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1731, 'end': 1739, 'text': 'improved'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.6927511096000671,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1854, 'end': 1863, 'text': 'increased'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.8483147621154785,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1864, 'end': 1869, 'text': '17.1%'},
#         'type': 'VALUE',
#         'producer_id': None,
#         'confidence': 0.7131310883303523,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1877, 'end': 1885, 'text': 'West Elm'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.5833545050362784,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1954, 'end': 1963, 'text': 'increases'},
#         'type': 'FINANCIAL_OUTCOME',
#         'producer_id': None,
#         'confidence': 0.7394920587539673,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 1968, 'end': 1988, 'text': 'Williams-Sonoma Home'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.5653123487012655,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''},
#        {'span': {'begin': 2068, 'end': 2074, 'text': 'retail'},
#         'type': 'PRODUCT_SERVICE',
#         'producer_id': None,
#         'confidence': 0.38574737310409546,
#         'mention_type': 'MENTT_UNSET',
#         'mention_class': 'MENTC_UNSET',
#         'role': ''}],
#       'producer_id': {'name': 'Entity-Mentions Transformer Workflow',
#        'version': '0.0.1'}}]]}]}
